# %% [markdown]
# # Given a Perceptron Equation

# %% [markdown]
# <h2><center> y = σ(−4.79x<sub>1</sub> + 5.90x<sub>2</sub> − 0.93) </center></h2>
#
# <h4>For the inputs defined in the domain [−2, 2] × [−2, 2], plot the output surface y as a function of
# x1, x2, when the activation function is (a) sigmoid (b) Hard limit and (c) Radial basis function. Plot
# the function with with 100, 5000, 10000, sample points from the domain. </h4>

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Definitions

# %%
lower_x1 = -2
upper_x1 = 2
lower_x2 = -2
upper_x2 = 2
sample_points_list = [100, 5000, 10000]

# %% [markdown]
# # Implement Functions

# %% [markdown]
# ### Activation Functions

# %%
def sigmoid(x):
    # implemented sigmoid function with slope = -0.5
    # slope > 1 means steeper curve 
    # slove < 1 means shallow curve
    
    return 1 / (1 + np.exp(-0.5 * x))

def hard_limit(x):
    # f(x) = 1, if x >= 0
    # f(x) = 0, otherwise

    return [1 if ele >= 0 else 0 for ele in x]
    
def radial_basis(x):
    # gaussian function 
    # y = e ^ (-gamma * x^2)
    # gamma = 0.05 ---> smoothing factor 
    
    return np.exp(-0.05 * ( x**2))

# %% [markdown]
# ### Get Random Domain Points of Sample Size

# %%
def generate_input(sample_size):
    # Generate random x1 and x2 points from given domain
    
    x1 = np.random.uniform(low=lower_x1, high=upper_x1, size=sample_size)
    x2 = np.random.uniform(low=lower_x2, high=upper_x2, size=sample_size)

    return x1, x2

# %% [markdown]
# # Visualization

# %%
def visualization(x1, x2, y, activation):
    # plot 3 sub-images for 3 different domain size

    fig = plt.figure(figsize=(16, 5))
    fig.suptitle(f'Output Surface for {activation} Activation Function', ha='center', fontsize=15)

    ax1 = fig.add_subplot(1, 3, 1, projection='3d')
    ax1.view_init(15, 60)
    ax1.scatter(x1[0], x2[0], y[0], c=y[0], cmap='coolwarm')
    ax1.set_xlabel('x1')
    ax1.set_ylabel('x2')
    ax1.set_zlabel('y')
    ax1.set_title('Sample Size 100', fontsize=15, y=-0.1)
    
    ax2 = fig.add_subplot(1, 3, 2, projection='3d')
    ax2.view_init(15, 60)
    ax2.scatter(x1[1], x2[1], y[1], c=y[1], cmap='coolwarm')
    ax2.set_xlabel('x1')
    ax2.set_ylabel('x2')
    ax2.set_zlabel('y')
    ax2.set_title('Sample Size 5000', fontsize=15, y=-0.1)
    
    ax3 = fig.add_subplot(1, 3, 3, projection='3d')
    ax3.view_init(15, 60)
    ax3.scatter(x1[2], x2[2], y[2], c=y[2], cmap='coolwarm')
    ax3.set_xlabel('x1')
    ax3.set_ylabel('x2')
    ax3.set_zlabel('y')
    ax3.set_title('Sample Size 10000', fontsize=15, y=-0.1)

    filename = f'./Images/Problem_2/{activation}.pdf'
    plt.savefig(filename)

# %% [markdown]
# # Generate y with x1 and x2

# %% [markdown]
# ### For Sigmoid Activation Function

# %%
complete_x1 = list()
complete_x2 = list()
complete_y = list()

for sample_size in sample_points_list:
    x1, x2 =  generate_input(sample_size)
    y = sigmoid(-4.79 * x1 + 5.9 * x2 - 0.93)

    complete_x1.append(x1)
    complete_x2.append(x2)
    complete_y.append(y)
    
visualization(complete_x1, complete_x2, complete_y, 'Sigmoid')

# %% [markdown]
# ### For Hard Limit Activation Function

# %%
complete_x1 = list()
complete_x2 = list()
complete_y = list()

for sample_size in sample_points_list:
    x1, x2 =  generate_input(sample_size)
    y = hard_limit(-4.79 * x1 + 5.9 * x2 - 0.93)

    complete_x1.append(x1)
    complete_x2.append(x2)
    complete_y.append(y)
    
visualization(complete_x1, complete_x2, complete_y, 'Hard_limit')

# %% [markdown]
# ### For Radial Basis Activation Function

# %%
complete_x1 = list()
complete_x2 = list()
complete_y = list()

for sample_size in sample_points_list:
    x1, x2 =  generate_input(sample_size)
    y = radial_basis(-4.79 * x1 + 5.9 * x2 - 0.93)

    complete_x1.append(x1)
    complete_x2.append(x2)
    complete_y.append(y)
    
visualization(complete_x1, complete_x2, complete_y, 'Radial Basis')
